# %%
rabbits:list[str] = ["flopsy", "Mopsy", "Cttontail", "Peter"]
for  rab in rabbits:
    print(rab)
# Out:
# flopsy
# Mopsy
# Cttontail
# Peter

# %%
country_code : dict[str,str ]= {"tw": "Taiwan",  "jp": "Japan", "hk": "Hong Kong", "kr": "Korea"}
for code in country_code:
    print(f"key:{code}")
    print(f"value:{country_code[code]}")
    print("=================")
# Out:
# key:tw
# value:Taiwan
# =================
# key:jp
# value:Japan
# =================
# key:hk
# value:Hong Kong
# =================
# key:kr
# value:Korea
# =================
