# %% [markdown]
# <a href="https://colab.research.google.com/github/LINLCLCC/06_17_playwight/blob/main/lession1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 13 
if a>=14: 
    a -= 2
    print(a)
else:
    a +=2
    
    print (a)
# Out:
# 15

# %%
print("Hello! world")
# Out:
# Hello! world

# %% [markdown]
# 上面是第一節上課的內容

# %%
5
5.5
"5.5"
# Out:
# '5.5'

# %%
5+5
5*5
"5.5"
# Out:
# '5.5'

# %%
print(5+5)
print(5*5)
print(7/3)
print(7//3)
# Out:
# 10
# 25
# 2.3333333333333335
# 2
